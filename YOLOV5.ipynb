# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 92.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="dcFeBmV5bbC4srfbDQdh")
project = rf.workspace("virtual-operator").project("virtual-operator-final-9clis")
version = project.version(3)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Virtual-Operator-Final-3 in yolov5pytorch:: 100%|██████████| 10802/10802 [00:01<00:00, 6942.18it/s]

# %%
# 1. Install YOLOv5
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17564, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 17564 (delta 33), reused 7 (delta 7), pack-reused 17510 (from 3)
# Receiving objects: 100% (17564/17564), 16.65 MiB | 22.47 MiB/s, done.
# Resolving deltas: 100% (12035/12035), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.4 MB/s eta 0:00:00
# ...

# %%
# 2. Train on your dataset
# data.yaml -> path to your dataset
# nc -> number of classes
# !python train.py --img 640 --batch 16 --epochs 15 --data /content/Virtual-Operator-Final-3/data.yaml --weights yolov5s.pt --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#        6/14      4.35G     0.0223    0.01181    0.01269         43        640:  63% 185/295 [00:46<00:25,  4.34it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/14      4.35G    0.02233    0.01181    0.01272         44        640:  63% 186/295 [00:46<00:26,  4.04it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/14      4.35G     0.0223     0.0118    0.01271         36        640:  63% 187/295 [00:46<00:25,  4.31it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# 3. Export to TFLite
# !python export.py --weights YOLOV5.pt --include tflite --img 640
# Out:
# export: data=data/coco128.yaml, weights=['YOLOV5.pt'], imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from YOLOV5.pt with output shape (1, 25200, 10) (13.8 MB)
# 2025-09-06 15:15:12.034455: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
